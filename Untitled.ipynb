# %%
# !pip install sqlalchemy==1.3.9
# %load_ext sql
import csv, sqlite3

con = sqlite3.connect("my_data.db")
cur = con.cursor()
# !pip install pandas==1.1.5

import pandas
df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv")
df.to_sql("CENSUS_DATA", con, if_exists='replace', index=False,method="multi")

df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv")
df.to_sql("CHICAGO_CRIME_DATA", con, if_exists='replace', index=False, method="multi")

df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv")
df.to_sql("CHICAGO_PUBLIC_SCHOOLS", con, if_exists='replace', index=False, method="multi")


# %sql sqlite:///my_data.db
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# ...
#      |████████████████████████████████| 10.1 MB 1.8 MB/s eta 0:00:01
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.4
#     Uninstalling pandas-1.2.4:
#       Successfully uninstalled pandas-1.2.4
# ...
# /Users/ab/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:2779: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   name       (index) object 'falcon' 'parrot' 'lion' 'monkey'

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql ibm_db_sa://vtl60743:b4E2zBGu3oaQjtNW@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB?security=SSL

# %%
# %sql Select count(*) as total_number_of_crimes from CHICAGO_CRIME_DATA
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [(0,)]

# %%
# %%sql
# select * from CHICAGO_CRIME_DATA limit 10
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# []

# %%
# %%sql
# select count(*) from CHICAGO_CRIME_DATA WHERE ARREST = TRUE
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [(0,)]

# %%
# %%sql
# select name_of_school from CHICAGO_PUBLIC_SCHOOLS where (COMMUNITY_AREA_NUMBER between 10 and 15) and (healthy_school_certified ='Yes')
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [('Rufus M Hitch Elementary School',)]

# %%
# %sql Select count(*) as total_number_of_crimes from CHICAGO_CRIME_DATA
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [(533,)]

# %%
# %%sql
# select community_area_name from CENSUS_DATA where PER_CAPITA_INCOME < 11000;
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [('West Garfield Park',),
#  ('South Lawndale',),
#  ('Fuller Park',),
#  ('Riverdale',)]

# %%
# %%sql
# select CASE_NUMBER from CHICAGO_CRIME_DATA where PRIMARY_TYPE = 'OFFENSE INVOLVING CHILDREN';
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# []

# %%
# %sql 
select case_number ,primary_type, description from CHICAGO_CRIME_DATA where primary_type='KIDNAPPING' and 
description like '%CHILD%';
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [('HN144152', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER')]

# %%
# %sql select name_of_school, primary_type from  CHICAGO_PUBLIC_SCHOOLS, schools s\
where c.community_area_number = s.community_area_number limit 5;
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0204N  "VTL60743.SCHOOLS" is an undefined name.  SQLSTATE=42704 SQLCODE=-204
# [SQL: select name_of_school, primary_type from CHICAGO_PUBLIC_SCHOOLS, schools s where c.community_area_number = s.community_area_number limit 5;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql 
select "Elementary, Middle, or High School", avg(safety_score) as average_safety_score from CHICAGO_PUBLIC_SCHOOLS 
group by "Elementary, Middle, or High School";CHICAGO_PUBLIC_SCHOOLS
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [(49,)]

# %%
# %sql select community_area_name, percent_households_below_poverty from CENSUS_DATA\
order by percent_households_below_poverty desc nulls last limit 5;
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [('Riverdale', Decimal('56.5')),
#  ('Fuller Park', Decimal('51.2')),
#  ('Englewood', Decimal('46.6')),
#  ('North Lawndale', Decimal('43.1')),
#  ('East Garfield Park', Decimal('42.4'))]

# %%
# %sql select community_area_number, count(*) as Number_of_Crime from  CHICAGO_CRIME_DATA group by community_area_number\
order by number_of_crime desc limit 1;
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [(25, 43)]

# %%
# %sql select community_area_name from CENSUS_DATA\
where hardship_index = (select max(hardship_index) from CENSUS_DATA)
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [('Riverdale',)]

# %%
# %sql create view num_crime as\
select community_area_number,community_area_name,  count(*) as number_of_crime\
from CHICAGO_CRIME_DATA group by community_area_number, community_area_name, ;
# %sql select * from num_crime limit 5;
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: Statement Execute Failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0104N  An unexpected token "END-OF-STATEMENT" was found following "community_area_name,".  Expected tokens may include:  "<grouping_exp_ref>".  SQLSTATE=42601 SQLCODE=-104
# [SQL: create view num_crime as select community_area_number,community_area_name, count(*) as number_of_crime from CHICAGO_CRIME_DATA group by community_area_number, community_area_name, ;]
# (Background on this error at: http://sqlalche.me/e/f405)
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [(1, 6), (2, 7), (3, 4), (4, 3), (5, 4)]

# %%
# %sql select community_area_name, community_area_number  from CHICAGO_PUBLIC_SCHOOLS s\
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# [('COMMUNITY_AREA_NAME', None),
#  ('LINCOLN PARK', 7),
#  ('SOUTH SHORE', 43),
#  ('ASHBURN', 70),
#  ('NEW CITY', 61),
#  ('ARMOUR SQUARE', 34),
#  ('ALBANY PARK', 14),
#  ('NORTH CENTER', 5),
#  ('WEST TOWN', 24),
#  ('NORTH CENTER', 5),
#  ('ALBANY PARK', 14),
#  ('NORTH CENTER', 5),
#  ('NEW CITY', 61),
#  ('LAKE VIEW', 6),
#  ('WEST TOWN', 24),
#  ('ROSELAND', 49),
#  ('ROSELAND', 49),
#  ('HUMBOLDT PARK', 23),
#  ('BEVERLY', 72),
#  ('EAST GARFIELD PARK', 27),
#  ('NORTH LAWNDALE', 29),
#  ('CALUMET HEIGHTS', 48),
#  ('LOGAN SQUARE', 22),
#  ('ENGLEWOOD', 68),
#  ('WEST TOWN', 24),
#  ('WOODLAWN', 42),
#  ('NEAR WEST SIDE', 28),
#  ('WEST ENGLEWOOD', 67),
#  ('MOUNT GREENWOOD', 74),
#  ('WEST TOWN', 24),
#  ('GRAND BOULEVARD', 38),
#  ('KENWOOD', 39),
#  ('WEST ENGLEWOOD', 67),
#  ('SOUTH CHICAGO', 46),
# ...

# %%
# %%sql
# Select community_area_number, community_area_name FROM CHICAGO_CENSUS WHERE community_area_number = (
#      SELECT community_area_number FROM (
#          SELECT community_area_number, COUNT(community_area_number) AS CRIME_COUNT FROM CHICAGO_CRIMES GROUP BY community_area_number
#      )
#      WHERE CRIME_COUNT = (
#          SELECT MAX(CRIME_COUNT) FROM (
#             SELECT community_area_number, COUNT(community_area_number) AS CRIME_COUNT FROM CHICAGO_CRIMES GROUP BY community_area_number
#          )
#      )
# )
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0204N  "VTL60743.CHICAGO_CENSUS" is an undefined name.  SQLSTATE=42704 SQLCODE=-204
# [SQL: Select community_area_number, community_area_name FROM CHICAGO_CENSUS WHERE community_area_number = (
#      SELECT community_area_number FROM (
#          SELECT community_area_number, COUNT(community_area_number) AS CRIME_COUNT FROM CHICAGO_CRIMES GROUP BY community_area_number
#      )
#      WHERE CRIME_COUNT = (
#          SELECT MAX(CRIME_COUNT) FROM (
#             SELECT community_area_number, COUNT(community_area_number) AS CRIME_COUNT FROM CHICAGO_CRIMES GROUP BY community_area_number
#          )
#      )
# )]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# SELECT * FROM CHICAGO_CRIME_DATA WHERE LOCATION_DESCRIPTION LIKE '%SCHOOLS%'
# Out:
#  * ibm_db_sa://vtl60743:***@764264db-9824-4b7c-82df-40d1b13897c2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:32536/BLUDB
#    sqlite:///my_data.db
# Done.
# []
